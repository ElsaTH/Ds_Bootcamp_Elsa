# %% [markdown]
# # Visualización de datos

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cancer_test_data.csv") #Relative

# %%
df = pd.read_csv("Z:\\Data_Science\\TheBridge\\Content\\Contenido_Curso\\data_science_jun_2020\\week3\\day5\\data\\cancer_test_data.csv") #Absolute

# %%
df
# Out:
#       patient_id test_result  has_cancer
# 0          79452    Negative       False
# 1          81667    Positive        True
# 2          76297    Negative       False
# 3          36593    Negative       False
# 4          53717    Negative       False
# ...          ...         ...         ...
# 2909       39378    Negative       False
# 2910       58684    Negative       False
# 2911       64038    Negative       False
# 2912       61290    Positive       False
# 2913       75721    Positive       False
#
# [2914 rows x 3 columns]

# %%
print(df.mean())
# Out:
# patient_id    56196.837337
# has_cancer        0.105010
# dtype: float64
# pandas.core.series.Series

# %%
df["patient_id"]
# Out:
# 79452

# %%
print(type(df["patient_id"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
test_result = df['test_result'].value_counts()
test_result
# Out:
# Negative    2106
# Positive     808
# Name: test_result, dtype: int64

# %%
test_result["Negative"]
# Out:
# 2106

# %%
type(test_result)
# Out:
# pandas.core.series.Series

# %%
test_result[0]
# Out:
# 2106

# %%
df.plot()
