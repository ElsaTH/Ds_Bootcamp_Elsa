# %% [markdown]
# # Preparando el entorno - Workout

# %% [markdown]
# ## Una pequeña introducción
#
# Hay dos opciones para realizar los ejercicio y trabajar con este precurso. La primera es ejecutar y visualizar los notebooks en Google Colab. En ese caso puedes ignorar esta sección y saltar a la sección  **"Nuestros primeros programas"**. En el tercer tema del precurso veremos las herramientas y explicaremos con mayor detalle la instalación del emtorno.
#
# En caso de que prefieras instalar localmente las herramientas en tu ordenador, la manera más sencilla es utilizar Anaconda.
# Anaconda es un gestor de paquetes que instala librerias que son utilizadas en Daata Science. Además es un gestor de entornos, y proporciona herramientas como los IDEs de desarrollo.
#
# Además de utilizar Anaconda en algun momento utilizaremos pip, otro gestor de paquetes, que es también muy popular y de propósito más general
#
# ## Instalando y comprobando el entorno
# Para la instalación vamos a utlizara las instrucciones que podeis encontrar en el siguiente enlace: https://docs.anaconda.com/anaconda/install/

# %%
from IPython.display import IFrame
IFrame(src ="https://docs.anaconda.com/anaconda/install/", width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://docs.anaconda.com/anaconda/install/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Comprobación del entorno
#
#
# En este ejercicio vamos a comprobar que tenemos correctamente configurado el entorno.
#
# - Comprobar la versión de python instalada.
# - Obtener la lista de paquetes instalada usando conda

# %%
IFrame(src = "https://kapeli.com/cheat_sheets/Conda.docset/Contents/Resources/Documents/index", width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://kapeli.com/cheat_sheets/Conda.docset/Contents/Resources/Documents/index"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Empezando a usar los notebooks en local
#
# Una vez instalado Anaconda lo más sencillo es abrir el Navigator de Anaconda, y desde alli arrancar Jupyter Notebook, o Jupyper Lab. Cuando hablemos de entornos de desarrollo, de nuevo entraremos en más detalles, y veremos ambos.
#
# Tienes un tutorial muy rápido sobre la utilización de Jupyter Notebook aquí: https://nbviewer.jupyter.org/github/jupyter/notebook/blob/master/docs/source/examples/Notebook/Notebook%20Basics.ipynb
#
# Una vez arrancado deberás utilizar el navegador de ficheros y abrir los ficheros .ipynb que componen este módulo.
#
#
#
#
# ----

# %% [markdown]
# # Como abordar el proceso de desarrollo. Nuestros primeros programas.
#
# Como hemos comentado en el vídeo introductorio del módulo, programar tiene que ver con la sintaxis y la semántica de un lenguaje, pero también tiene un componente de lógica, resolución de problemas, y pensamiento computacional. Esto es, como abordamos problemas desde la perspectiva del software.
#
# Por eso además de aprender semántica y sintaxis es importante entender que tenemos que hacer cuando abordamos la resolución de un problema a travñes del software. ¿Qué pasos tendremos que dar? ¿Qué es importante?
#
# 1. Entender el problema:
# - Que datos vamos a tener. Como nos van a llegar
# - Que esperamos obtener
# - Cuales son las transformaciones/acciones que tenemos que realizar?
#
# 2. Especificar una solución
# - Debemos definir de manera rápida que queremos obtener.
# - Cuales serán los inputs/oputpus.
# - Como es la interacción
#
# 3. Deseñar la soluciónDiseño de la solución
# - Aquí comenzamos a definir los componentes que tendrá nuestra solución
# - Como modelaremos los elementos de la misma de acuerdo a las capacidades que nos den las herramientas que vamos a usar
# - Definiremos funciones y métodos y/o clases.
# - definiremos las funcionalidades esperadas para cada método o función.
#
# 4. Implementación
# - Aquí es cuando empezamos a codificarcodificamos.
# - Tendremos que tener en cuenta que herramientas podemos reutilizar, que librerias usar,etc.
# - Codificamos
#
# 5. Pruebas
# - En el caso de Data Science, vamos a aproximarnos al proceso de una forma muy funcional y secuencial, así que aordaremos las pruebas sobre la propia ejecución, pero es común definir durante el diseño las pruebas unitarias y de integración, o incluso utilizar aproximaciones orientadas a testing como Test Driven Development.
#
#
# **MUY IMPORTANTE:NO EMPEZAR A CODIFICAR HASTA EL 4º PASO**

# %% [markdown]
# ## Un conversor de temperaturas
#
# El primer problema que vamos a abordar es construir un programa que nos ayude a convertir la temperatura de grados Celsius a Grados Farenheit
#
# - Qué tiene que hacer el programa?
#
#     - Entrada -> temperatura en grados Celsius
#     - Salida -> temperatura en grados Farenheit
#     - Salida = 9/5(entrada) + 32. Esta es la conversión matemática.
#
# - Diseño
#
#     - Tendremos que pedir la temperatura que queremos convertir
#     - Tendremos que procesarla para obtener la temperatira en ºF
#     - Tendremos que mostrar la temperatura
#
# - Antes de empezar a codificar hacemos una primera aproximación utilizando psudocodigo
#
#     - Input the temperature in degrees Celsius (call it celsius)
#     - Calculate fahrenheit as (9/5)*celsius+32
#     - Output fahrenheit

# %% [markdown]
# Vamos a realizar el programa. El objetivo no es que ahora escribas el código sino que trates de familiarizarte con el código. Además vamos a utilizar estos primeros programas para ver los componentes de los mismos, así que trata de identificarlos.

# %%
# Un programa que convierte grados Celsius a Farenheit

# entrada de datos. Pedimos al usuario que introduzca la temperatura

celsius = eval(input("What is the Celsius temperature? "))

# celsius = 22 

# Convertimos los grados celsius a grados farenheit segun la fórmula
fahrenheit = (9/5) * celsius + 32

# Imprimimos la temperatura en grados Farenheit

print("The temperature is ",fahrenheit," degrees Fahrenheit.")
# Out:
# What is the Celsius temperature? 15
# The temperature is  59.0  degrees Fahrenheit.

# %% [markdown]
# # Elementos de un programa
#
# **Comentarios** - permiten incluir descripciones al código sobre los objetivos, que se hace en cada lugar, etc. Es muy importante usarlos, porque nuestra memoria es peor de lo que creemos.
#
# **Nombres** - las funciones, variables, metodos, etc reciben identificadores. Son Case Sensitive, y debemos tratar de describir lo que estamos nombrando.
#
# **Expresiones** - Las expresiones son fragmentos de código que producen o calculan nuevos datos. Pueden ser desde la más sencilla, que es un literal hasta formulas más complejas o que ejecutan funciones o metodos.
#
# **Output Statments** - Permiten mostrar los datos, variables y resultados de expresiones.
#
# **Assigment statements** - permiten asignar valores a variables. En general tienen el formato <variable> = <expresion>
#
# **Assigning input** - Son casos de asignación que recojen entrada de los usuarios en general por el interfaz del programa.

# %% [markdown]
# ## Otro programa : Calculando el Valor futuro
#
# El programa deberá calcular el valor de una inversión conociendo el valor inicial, el interés anual, y lo hará inicialmente para un periodo de 10 años. Vamos a hacer el análisis
#
# Análisis
# - Money deposited in a bank account earns interest.
# - How much will the account be worth 10 years from now?
# - Inputs: principal, interest rate
# - Output: value of the investment in 10 years
#
# Especificación
# - User enters the initial amount to invest, the principal
# - User enters an annual percentage rate, the interest
# - The program uses the anual interest rate formula and applies it ten times.
#
# Diseño
# - Print an introduction
# - Input the amount of the principal (principal)
# - Input the annual percentage rate (apr)
# - Repeat 10 times:
#             principal = principal * (1 + apr)
# - Output the value of principal
#
#
# Para reprtir 10 veces vamos a usar un bucle for:
#
# <img src=https://drive.google.com/open?id=1uGS4EmEmq9d28vQqzTS-RaN85nwqJNN3>
#
# Vamos a programarlo. De nuevo no esperamos que seas capaz de programarlo, pero trata de entenderlo, y analiza que hace cada linea.

# %%
# futval.py
#    A program to compute the value of an investment
#    carried 10 years into the future


print("This program calculates the future value of a 10-year investment.")

# pedimos al usuario que introduzca el valor inicial
principal = eval(input("Enter the initial principal: "))

print(type(principal))

#pedimos al usuario que introduzca el interés anual 
apr = eval(input("Enter the annual interest rate: "))

periodo = int(input("Introduce el numero de años"))

# repetimos 10 veces la operación para el interés anual.
for i in range(periodo):                        # definimos un bucle con que iterará 10 veces
    principal = principal * (1 + apr)
    print("valor al final del año",i+1,"sera",principal)      # asignamos a principal el resultante de cada año

# imprimimos el resultado una vez acabado el bucle (atención a la identación)

print ("The value in 10 years is:", principal)
# Out:
# This program calculates the future value of a 10-year investment.
# Enter the initial principal: 999.99
# <class 'float'>
# Enter the annual interest rate: 0.02
# valor al final del año 1 sera 1019.9898000000001
# valor al final del año 2 sera 1040.389596
# valor al final del año 3 sera 1061.19738792
# valor al final del año 4 sera 1082.4213356784
# valor al final del año 5 sera 1104.069762391968
# valor al final del año 6 sera 1126.1511576398073
# valor al final del año 7 sera 1148.6741807926035
# valor al final del año 8 sera 1171.6476644084555
# valor al final del año 9 sera 1195.0806176966246
# valor al final del año 10 sera 1218.982230050557
# The value in 10 years is: 1218.982230050557
