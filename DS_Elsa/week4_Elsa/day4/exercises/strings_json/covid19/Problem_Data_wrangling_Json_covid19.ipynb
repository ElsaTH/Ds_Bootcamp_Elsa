# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='https://covid19tracking.narrativa.com/feed_en.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# est-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C577%2C758%29%2C%20Rusia%20%28317%2C554%29%2C%20Brasil%20%28310%2C087%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-ea8cbaaf336bf3da8d8d12b974b95e68',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>5,062,584</strong> people infected around the world',
#     'content': '<p><small>Narrativa | Friday, May 22, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,062,584</strong>, of which <strong>1,950,080</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,577,758</strong> recorded cases, followed by <b> Russia</b>, <b> Brazil</b>, and <b>The United Kingdom</b>, who have confirmed <strong>317,554, 310,087, and 252,246</strong> cases respectively.</p><h4>COVID-19 status across most infected countries</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,184,611</td><td>1. The US: 1,577,758</td><td>1. Pakistan: 2,603</td><td>1. The US: 94,729</td><td>1. Brazil: 20,047</td><td>1. The US: 298,418</strong></td><td>1. Italy: 2,278</strong></td></tr><tr><td>2. Russia: 221,774</td><td>2. Russia: 317,554</td><td>2. The United Kingdom: 1,338</td><td>2. The United Kingdom: 36,124</td><td>2. Italy: 156</td><td>2. Germany: 158,827</strong></td><td>2. Mexico: 1,733</strong></td></tr><tr><td>3. The United Kingdom: 214,988</td><td>3. Brazil: 310,087</td><td>3. The US: 1,216</td><td>3. Italy: 32,486</td><td>3. The United Kingdom: 82</td><td>3. Spain: 150,376</strong></td><td>3. Pakistan: 1,046</strong></td></tr></tbody></table></p><p>In addition, <strong>9,763</strong> new positive cases have been added in the last 24 hours, demonstrating a <strong>0.19</strong>% growth from the previous day. <strong> Pakistan</strong> is the country with the most new cases, having now confirmed <strong>2,603</strong>, followed by <b>The United Kingdom</b> with <strong>1,338</strong>. <strong>The US</strong> and <strong> Italy</strong> are not far behind, with <strong>642</strong> and <strong>642</strong> new patients respectively.</p><p> Also, <strong>Brazil</strong> registered their first deaths by COVID-19.</p><p>Since the beginning, <strong>the total number of deaths from coronavirus worldwide</strong> is <strong>322,493 people</strong>, including the <strong>20,598</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>94,729</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>36,124, 32,486, and 27,940</strong> deaths respectively.</p><p>The first evidences about this new strain of COVID-19 appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, the infection has spread across Asia and the world. As of the latest reports, cases in China have grown to <strong>16</strong> new cases since yesterday. Overall, <strong>112</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C577%2C758&top_paises2=Rusia%3A%20317%2C554&top_paises3=Brasil%3A%20310%2C087&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Rusia&top_paises3=Brasil&top_paises1_num=1%2C577%2C758&top_paises2_num=317%2C554&top_paises3_num=310%2C087&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/22&gen_time=09%3A37&client=default_web&region=world',
#     '_id': 'c0df4d8ea28ebcf97a198fbf0296b585',
#     'id': '2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-22T08:45:29+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C577%2C287%29%2C%20Rusia%20%28317%2C554%29%2C%20Brasil%20%28310%2C087%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-0acc9c96d9ce5263f5c84747b333a5d0',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>322,462</strong> deaths confirmed around the world',
#     'content': '<p><small>Narrativa | Friday, May 22, 2020 </small></p><p>The total number of people infected is now <strong>5,061,167</strong> <strong>worldwide</strong> Amongst this number, <strong>1,949,049</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,577,287</strong>, followed by <b> Russia</b>, <b> Brazil</b>, and <b>The United Kingdom</b> with <strong>317,554, 310,087, and 252,246</strong> cases respectively.</p><h4>COVID-19 Status Worldwide</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,184,167</td><td>1. The US: 1,577,287</td><td>1. Pakistan: 2,603</td><td>1. The US: 94,702</td><td>1. Brazil: 20,047</td><td>1. The US: 298,418</strong></td><td>1. Italy: 2,278</strong></td></tr><tr><td>2. Russia: 221,774</td><td>2. Russia: 317,554</td><td>2. The United Kingdom: 1,338</td><td>2. The United Kingdom: 36,124</td><td>2. Italy: 156</td><td>2. Germany: 158,427</strong></td><td>2. Mexico: 1,733</strong></td></tr><tr><td>3. The United Kingdom: 214,988</td><td>3. Brazil: 310,087</td><td>3. The US: 745</td><td>3. Italy: 32,486</td><td>3. The United Kingdom: 82</td><td>3. Spain: 150,376</strong></td><td>3. Pakistan: 1,046</strong></td></tr></tbody></table></p><p>In addition, the last 24 hours have seen <strong>8,346</strong> new positive cases added in the last 24 hours, an increase of <strong>0.17</strong>% from the previous day. <strong> Pakistan</strong> is the country with the most new cases, having now confirmed <strong>2,603</strong>, followed by <b>The United Kingdom</b> with <strong>1,338</strong>. <strong>The US</strong> and <strong> Italy</strong> are not far behind, with <strong>642</strong> and <strong>642</strong> new patients respectively.</p><p> Also, <strong>Brazil</strong> registered their first deaths by COVID-19.</p><p>As it stands, <strong>the number of COVID-19 related deaths worldwide</strong> stands at <strong>322,462 people</strong>, including the <strong>20,567</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>94,702</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>36,124, 32,486, and 27,940</strong> deaths respectively.</p><p>The first news of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and later to other countries around the world. As of the latest reports, cases in China have grown to <strong>16</strong> new cases since yesterday. Overall, <strong>112</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C577%2C287&top_paises2=Rusia%3A%20317%2C554&top_paises3=Brasil%3A%20310%2C087&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Rusia&top_paises3=Brasil&top_paises1_num=1%2C577%2C287&top_paises2_num=317%2C554&top_paises3_num=310%2C087&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/22&gen_time=08%3A41&client=default_web&region=world',
#     '_id': 'c0df4d8ea28ebcf97a198fbf0266a986',
#     'id': '2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
print(json_readed)
# Out:
# munidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/22&gen_time=10%3A38&client=default_web&region=world', '_id': 'c0df4d8ea28ebcf97a198fbf02d27f74', 'id': '2020-5-22-10_01-COVID-world-en_generic_COVID_EN_GENERIC'}, {'date': '2020-05-22T09:45:01+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C577%2C758%29%2C%20Rusia%20%28317%2C554%29%2C%20Brasil%20%28310%2C087%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%2 ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# ades3_num=18%2C627&gen_date=2020/05/22&gen_time=10%3A38&client=default_web&region=world", "_id": "c0df4d8ea28ebcf97a198fbf02d27f74", "id": "2020-5-22-10_01-COVID-world-en_generic_COVID_EN_GENERIC"}, {"date": "2020-05-22T09:45:01+02:00", "metadata": {"picurl_square_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default", "picurl_square_spain_extended": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true", "graphs": {"graph_picurl_china": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png", "graph_picurl_us": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png", "graph_picurl_deaths_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png", "graph_picurl_world": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png", "graph_picurl_china_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png", "graph_picurl_us_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png", "graph_picurl_spain_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png", "graph_picurl_us_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png", "graph_picurl_deaths_log_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png", "graph_picurl_italy": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png", "graph_picurl_italy_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png", "graph_picurl_us_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png", "graph_picurl_italy_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png", "graph_picurl_china_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png", "graph_picurl_italy_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png", "graph_picurl_spain_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png", "graph_picurl_china_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png"}, "picurl_square_world": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default", "picurl_16_9_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C577%2C758%29%2C%20Rusia%20%28317%2C554%29%2C%20Brasil%20%28310%2C087%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ra ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# est-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C577%2C758%29%2C%20Rusia%20%28317%2C554%29%2C%20Brasil%20%28310%2C087%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-ea8cbaaf336bf3da8d8d12b974b95e68',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>5,062,584</strong> people infected around the world',
#     'content': '<p><small>Narrativa | Friday, May 22, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,062,584</strong>, of which <strong>1,950,080</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,577,758</strong> recorded cases, followed by <b> Russia</b>, <b> Brazil</b>, and <b>The United Kingdom</b>, who have confirmed <strong>317,554, 310,087, and 252,246</strong> cases respectively.</p><h4>COVID-19 status across most infected countries</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,184,611</td><td>1. The US: 1,577,758</td><td>1. Pakistan: 2,603</td><td>1. The US: 94,729</td><td>1. Brazil: 20,047</td><td>1. The US: 298,418</strong></td><td>1. Italy: 2,278</strong></td></tr><tr><td>2. Russia: 221,774</td><td>2. Russia: 317,554</td><td>2. The United Kingdom: 1,338</td><td>2. The United Kingdom: 36,124</td><td>2. Italy: 156</td><td>2. Germany: 158,827</strong></td><td>2. Mexico: 1,733</strong></td></tr><tr><td>3. The United Kingdom: 214,988</td><td>3. Brazil: 310,087</td><td>3. The US: 1,216</td><td>3. Italy: 32,486</td><td>3. The United Kingdom: 82</td><td>3. Spain: 150,376</strong></td><td>3. Pakistan: 1,046</strong></td></tr></tbody></table></p><p>In addition, <strong>9,763</strong> new positive cases have been added in the last 24 hours, demonstrating a <strong>0.19</strong>% growth from the previous day. <strong> Pakistan</strong> is the country with the most new cases, having now confirmed <strong>2,603</strong>, followed by <b>The United Kingdom</b> with <strong>1,338</strong>. <strong>The US</strong> and <strong> Italy</strong> are not far behind, with <strong>642</strong> and <strong>642</strong> new patients respectively.</p><p> Also, <strong>Brazil</strong> registered their first deaths by COVID-19.</p><p>Since the beginning, <strong>the total number of deaths from coronavirus worldwide</strong> is <strong>322,493 people</strong>, including the <strong>20,598</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>94,729</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>36,124, 32,486, and 27,940</strong> deaths respectively.</p><p>The first evidences about this new strain of COVID-19 appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, the infection has spread across Asia and the world. As of the latest reports, cases in China have grown to <strong>16</strong> new cases since yesterday. Overall, <strong>112</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C577%2C758&top_paises2=Rusia%3A%20317%2C554&top_paises3=Brasil%3A%20310%2C087&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C062%2C584&actives_num=2%2C790%2C011&recovered_num=1%2C950%2C080&deaths_num=322%2C493&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Rusia&top_paises3=Brasil&top_paises1_num=1%2C577%2C758&top_paises2_num=317%2C554&top_paises3_num=310%2C087&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/22&gen_time=09%3A37&client=default_web&region=world',
#     '_id': 'c0df4d8ea28ebcf97a198fbf0296b585',
#     'id': '2020-5-22-09_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-22T08:45:29+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C577%2C287%29%2C%20Rusia%20%28317%2C554%29%2C%20Brasil%20%28310%2C087%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-0acc9c96d9ce5263f5c84747b333a5d0',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>322,462</strong> deaths confirmed around the world',
#     'content': '<p><small>Narrativa | Friday, May 22, 2020 </small></p><p>The total number of people infected is now <strong>5,061,167</strong> <strong>worldwide</strong> Amongst this number, <strong>1,949,049</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,577,287</strong>, followed by <b> Russia</b>, <b> Brazil</b>, and <b>The United Kingdom</b> with <strong>317,554, 310,087, and 252,246</strong> cases respectively.</p><h4>COVID-19 Status Worldwide</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,184,167</td><td>1. The US: 1,577,287</td><td>1. Pakistan: 2,603</td><td>1. The US: 94,702</td><td>1. Brazil: 20,047</td><td>1. The US: 298,418</strong></td><td>1. Italy: 2,278</strong></td></tr><tr><td>2. Russia: 221,774</td><td>2. Russia: 317,554</td><td>2. The United Kingdom: 1,338</td><td>2. The United Kingdom: 36,124</td><td>2. Italy: 156</td><td>2. Germany: 158,427</strong></td><td>2. Mexico: 1,733</strong></td></tr><tr><td>3. The United Kingdom: 214,988</td><td>3. Brazil: 310,087</td><td>3. The US: 745</td><td>3. Italy: 32,486</td><td>3. The United Kingdom: 82</td><td>3. Spain: 150,376</strong></td><td>3. Pakistan: 1,046</strong></td></tr></tbody></table></p><p>In addition, the last 24 hours have seen <strong>8,346</strong> new positive cases added in the last 24 hours, an increase of <strong>0.17</strong>% from the previous day. <strong> Pakistan</strong> is the country with the most new cases, having now confirmed <strong>2,603</strong>, followed by <b>The United Kingdom</b> with <strong>1,338</strong>. <strong>The US</strong> and <strong> Italy</strong> are not far behind, with <strong>642</strong> and <strong>642</strong> new patients respectively.</p><p> Also, <strong>Brazil</strong> registered their first deaths by COVID-19.</p><p>As it stands, <strong>the number of COVID-19 related deaths worldwide</strong> stands at <strong>322,462 people</strong>, including the <strong>20,567</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>94,702</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>36,124, 32,486, and 27,940</strong> deaths respectively.</p><p>The first news of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and later to other countries around the world. As of the latest reports, cases in China have grown to <strong>16</strong> new cases since yesterday. Overall, <strong>112</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C577%2C287&top_paises2=Rusia%3A%20317%2C554&top_paises3=Brasil%3A%20310%2C087&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C061%2C167&actives_num=2%2C789%2C656&recovered_num=1%2C949%2C049&deaths_num=322%2C462&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=22%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Rusia&top_paises3=Brasil&top_paises1_num=1%2C577%2C287&top_paises2_num=317%2C554&top_paises3_num=310%2C087&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/22&gen_time=08%3A41&client=default_web&region=world',
#     '_id': 'c0df4d8ea28ebcf97a198fbf0266a986',
#     'id': '2020-5-22-08_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                                    data
# post  [{'date': '2020-07-06T23:02:22+02:00', 'metada...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
# your code...
