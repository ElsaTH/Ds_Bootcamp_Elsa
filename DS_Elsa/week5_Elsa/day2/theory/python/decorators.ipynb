# %%
@nombre_decorador
def function():
    print("1")

# %%
# defining a decorator 
def hello_decorator(func): 
    def inner1(): 
        print("Hello, this is before function execution") 
        func() 
        print("This is after function execution") 
    return inner1 
  
  
# defining a function, to be called inside wrapper 
def function_to_be_used(): 
    print("This is inside the function !!") 

  
# passing 'function_to_be_used' inside the 
# decorator to control its behavior 
function_to_be_used = hello_decorator(func=function_to_be_used) 
  
  
# calling the function 
function_to_be_used()
# Out:
# Hello, this is before function execution
# This is inside the function !!
# This is after function execution

# %%
import time 

print(time.time())
# Out:
# 1594712498.4873881

# %%
5!
5*4*3*2*1

# %%
# importing libraries 
import time 
import math 

def calculate_time(func): 
    def inner1(*args, **kwargs):
        print("Anterior") 
        begin = time.time() 
        time.sleep(1)
        func(*args, **kwargs) 
        end = time.time() 
        print("Total time", end - begin, " seconds") 
    return inner1 

@calculate_time
def factorial(num): 
    #time.sleep(2) 
    print(math.factorial(num)) 
  
factorial(num=2)
# Out:
# Anterior
# 2
# Total time 1.0005817413330078  seconds

# %%
@calculate_time
def x():
    print("2")

x()
# Out:
# Anterior
# 2
# Total time 1.0002176761627197  seconds

# %%
def ar(*args):
    print(args)

ar(1,5,7,3,"g")
# Out:
# (1, 5, 7, 3, 'g')

# %%
def kwar(**kwargs):
    print(kwargs)

kwar(x=1, y=5, z=7, h=3, m="g")
# Out:
# {'x': 1, 'y': 5, 'z': 7, 'h': 3, 'm': 'g'}

# %%
def decorator(*args, **kwargs): 
    print("Inside decorator") 
    def inner(func): 
        print("Inside inner function") 
        print("I like", kwargs['like'])  
        return func
    return inner 

@decorator(like="geeksforgeeks") 
def func(): 
    print("Inside actual function") 
  
func()
# Out:
# Inside decorator
# Inside inner function
# I like geeksforgeeks
# Inside actual function

# %%
from functools import wraps
from datetime import datetime
import math
import time

def decorator_v2(timed):
    def real_decorator(function):
        @wraps(function)
        def wrapper(*args, **kwargs):
            if timed:
                begin_2 = datetime.now()
                print("begin_2:", begin_2)
            retval = function(*args, **kwargs)
            if timed:
                end_2 = datetime.now()
                print("end_2:", end_2)
                print("--------------")
                print("With datetime:")
                print("Total datetime: ", end_2 - begin_2, " seconds") 
            return retval
        return wrapper
    return real_decorator

@decorator_v2(timed=True)
def fact(a):
    return math.factorial(a)

fact(100000)
# Out:
# begin_2: 2020-07-14 10:21:36.021858
# end_2: 2020-07-14 10:21:36.137575
# --------------
# With datetime:
# Total datetime:  0:00:00.115717  seconds
# ...

# %%
@decorator_v2(timed=True)
def fact(a):
    time.sleep(2)
    return math.factorial(a)

fact(6)
# Out:
# --------------
# With time:
# Total time:  2.0001561641693115  seconds
# --------------
# With datetime:
# Total datetime:  0:00:02.000157  seconds
# 720

# %%
from functools import wraps
from datetime import datetime
import math
import time

def nombre_decorador(timed):
    def inner(function):
        @wraps(function)
        def wrapper(*args, **kwargs):
            # antes
            retval = function(*args, **kwargs)
            # después
            return retval
        return wrapper
    return inner

@nombre_decorador(timed=True)
def fact(a):
    return math.factorial(a)

fact(a=1000)
# Out:
# ...
