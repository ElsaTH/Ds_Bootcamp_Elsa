# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='https://covid19tracking.narrativa.com/feed_en.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# 0y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=12%3A36&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf6def733',
#     'id': '2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-27T11:06:53+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
# ...

# %%
print(json_readed)
# Out:
# eaths_num=341%2C118&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=12%3A36&client=default_web&region=world', '_id': '6658f6eb15b745e282dee2ccf6def733', 'id': '2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC'}, {'date': '2020-05-27T11:06:53+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picur
# ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# ed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=12%3A36&client=default_web&region=world", "_id": "6658f6eb15b745e282dee2ccf6def733", "id": "2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC"}, {"date": "2020-05-27T11:06:53+02:00", "metadata": {"picurl_square_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default", "picurl_square_spain_extended": "https://4i2g925ohj.execute-api.eu-west
# ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                                    data
# post  [{'date': '2020-07-12T12:02:30+02:00', 'metada...

# %%
# Coloco los datos de la tabla y pongo el índice con números:

# %%
df_json2 = df_json.rename_axis('post').reset_index()
df_json2
# Out:
#    post                                               data
# 0  post  [{'date': '2020-07-12T12:02:30+02:00', 'metada...

# %%
type(df_json2)
# Out:
# pandas.core.frame.DataFrame

# %%
## Data es el elemento al que quiero acceder, pero tiene una lista y dentro diccionarios
## Primero obtengo el diccionario

# %%
new_dict= df_json2.data[0][0]
print(type(new_dict))
# Out:
# <class 'dict'>

# %%
# para poder seguir trabajando construyo otro DataFrame
df_covid = pd.DataFrame(new_dict)
df_covid
# Out:
#                                                    date  \
# composition_type              2020-07-12T12:02:30+02:00
# country_selected              2020-07-12T12:02:30+02:00
# graphs                        2020-07-12T12:02:30+02:00
# picurl_16_9_spain             2020-07-12T12:02:30+02:00
# picurl_square_spain           2020-07-12T12:02:30+02:00
# picurl_square_spain_extended  2020-07-12T12:02:30+02:00
# picurl_square_world           2020-07-12T12:02:30+02:00
# picurl_square_world_extended  2020-07-12T12:02:30+02:00
# state_selected                2020-07-12T12:02:30+02:00
#
#                                                                        metadata  \
# composition_type                                                          world
# country_selected                                                           None
# graphs                        {'graph_picurl_china': 'https://resources.gabr...
# picurl_16_9_spain             https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
df_covid["metadata"]
df_covid
# Out:
#                                                    date  \
# composition_type              2020-07-12T12:02:30+02:00
# country_selected              2020-07-12T12:02:30+02:00
# graphs                        2020-07-12T12:02:30+02:00
# picurl_16_9_spain             2020-07-12T12:02:30+02:00
# picurl_square_spain           2020-07-12T12:02:30+02:00
# picurl_square_spain_extended  2020-07-12T12:02:30+02:00
# picurl_square_world           2020-07-12T12:02:30+02:00
# picurl_square_world_extended  2020-07-12T12:02:30+02:00
# state_selected                2020-07-12T12:02:30+02:00
#
#                                                                        metadata  \
# composition_type                                                          world
# country_selected                                                           None
# graphs                        {'graph_picurl_china': 'https://resources.gabr...
# picurl_16_9_spain             https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    for covid in df_covid["metadata"]:
        print(covid)
        break
# Out:
# world

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    for covid in df_covid["metadata"][2:]:
        print(covid)
        break
# Out:
# {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-12-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'g
# ...

# %%
# Guardamos los datos:

# %%
type(df_covid["metadata"][2:])
# Out:
# pandas.core.series.Series

# %%
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    metadata_json_list = json_readed["metadata"][2:] # No consigo como poner bien este dato para que no me siga dando error
metadata_json_list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-516c8300f020> in <module>
#       1 with open("data_indented.json", "r+") as outfile:
#       2     json_readed = json.load(outfile)
# ----> 3     metadata_json_list = json_readed["metadata"][2:] # No consigo como poner bien este dato para que no me siga dando error
#       4 metadata_json_list
#
# KeyError: 'metadata'

# %%
#### Como no consigo solucionar el error de arriba, no puedo terminar el ejercicio.
#### El restos de los pasos son los siguientes:

# %%
with open ("final_data.json", "w+") as outfile:
    json.dump(metadata_json_list, outfile, ident=4)
df_metadata_json

# %%
final_df = pd.concat([df_json,df_metadata_json],axis=1,scort=False)

# %%
final_df = final_df.drop([],axis=1, sort=False)
final_df
