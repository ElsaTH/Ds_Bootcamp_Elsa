# %% [markdown]
# ### 1. Se pide:
#
# A partir del archivo "USA_Housing.csv", realizar la regresión no lineal entre cada columna numérica con la columna 'price' utilizando:
#
# - Regresión polinómica no lineal con grados del 2 al 10. ¿El score se estanca a partir de cierto grado?
# - SVR

# %% [markdown]
# ### Regresión polinómica no lineal con grados del 2 al 10. ¿El score se estanca a partir de cierto grado?
# target = price

# %% [markdown]
# * Importamos librerías:

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import math
import decimal
from decimal import Decimal, getcontext
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

# %% [markdown]
# * Cargamos archivo

# %%
df = pd.read_csv("/Users/elsa/Desktop/Bootcamp The Bridge/The_Bridge/Ds_Bootcamp_Elsa/DS_Elsa/week8/day2/data/USA_Housing.csv")
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# * Dividimos el modelo:

# %%
del df["Address"]

# %%
X = df[df.columns[:-1]].values
y = df["Price"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

# %% [markdown]
# Compruebo que por ejemplo X_train es un array:

# %%
X_train
# Out:
# array([[7.02590684e+04, 6.75734532e+00, 7.68491170e+00, 6.05000000e+00,
#         5.40506447e+04],
#        [8.18986447e+04, 5.75692080e+00, 6.61601171e+00, 4.47000000e+00,
#         3.17642821e+04],
#        [5.30569210e+04, 5.18024357e+00, 9.53623862e+00, 6.49000000e+00,
#         3.57628706e+04],
#        ...,
#        [5.21881187e+04, 5.63689209e+00, 5.80740148e+00, 4.03000000e+00,
#         4.24957547e+04],
#        [5.15549245e+04, 7.28197890e+00, 6.52222048e+00, 4.22000000e+00,
#         3.68300803e+04],
#        [6.47808758e+04, 7.31380363e+00, 6.11046578e+00, 2.32000000e+00,
#         2.70270565e+04]])

# %%
y_train
# Out:
# array([1741052.95962204, 1529281.84011934, 1186662.51422549, ...,
#         783808.40246617,  979568.62854125, 1200060.66203741])

# %% [markdown]
# * Comprabamos los grados de 2 a 10:

# %%
degree = 2

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 91.80699737391718  %

# %%
degree = 3

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 91.88155756360167  %

# %%
degree = 4

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 91.9340337273153  %

# %%
degree = 5

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 91.76313649980976  %

# %%
degree = 6

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 89.8243593605897  %

# %%
degree = 7

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 91.35520789805133  %

# %%
degree = 8

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 90.00660347395149  %

# %%
degree = 9

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 88.67103796821135  %

# %%
degree = 10

polinominal_model = PolynomialFeatures(degree) 
X_poly = polinominal_model.fit_transform(X_train, y_train)

#######

lin_reg_model = LinearRegression()
lin_reg_model.fit(X_poly, y_train)
y_pred = lin_reg_model.predict(X_poly)

print("y_pred", y_pred.shape)
print("Score:", r2_score(y_train, y_pred)*100, " %")
# Out:
# y_pred (4000,)
# Score: 85.13285610283228  %

# %% [markdown]
# #### El Score no se estanga en ningún grado de los que hemos probado el mejor es para degree = 4.

# %% [markdown]
# ### Otra forma de hacer el modelo:
# Realiza el proceso de antes en con un for:
# Es la manera Profesional de hacerlo:

# %%
# Test/train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Min and max degree of polynomials features to consider
degree_min = 2
degree_max = 10
# Make a pipeline model with polynomial transformation and LASSO regression with cross-validation, run it for increasing degree of polynomial (complexity of the model)
scores = []
for degree in range(degree_min,degree_max+1):
    print("-----------------")
    print("polynominal linear regression with degree =", degree)
    polinominal_model = PolynomialFeatures(degree) 
    X_poly = polinominal_model.fit_transform(X_train,y_train)

    #######
    print(X_poly.shape)

    lin_reg_model = LinearRegression()
    lin_reg_model.fit(X_poly, y_train)
    y_pred = lin_reg_model.predict(X_poly)
    
    print(degree)
    print("y_pred", y_pred.shape)
    print("Score:", r2_score(y_train, y_pred))
# Out:
# -----------------
# polynominal linear regression with degree = 2
# (4000, 21)
# 2
# y_pred (4000,)
# Score: 0.917110794953276
# -----------------
# polynominal linear regression with degree = 3
# (4000, 56)
# 3
# y_pred (4000,)
# Score: 0.9177951160436548
# -----------------
# polynominal linear regression with degree = 4
# (4000, 126)
# 4
# y_pred (4000,)
# Score: 0.9112260352200972
# -----------------
# polynominal linear regression with degree = 5
# (4000, 252)
# 5
# y_pred (4000,)
# Score: 0.911610406956368
# -----------------
# polynominal linear regression with degree = 6
# (4000, 462)
# 6
# y_pred (4000,)
# Score: 0.8319182253158023
# -----------------
# polynominal linear regression with degree = 7
# (4000, 792)
# 7
# y_pred (4000,)
# Score: 0.8804581354214492
# -----------------
# polynominal linear regression with degree = 8
# (4000, 1287)
# 8
# y_pred (4000,)
# Score: 0.9016071462052251
# -----------------
# polynominal linear regression with degree = 9
# (4000, 2002)
# ...

# %%
X_train
# Out:
# array([[5.71364558e+04, 5.19715648e+00, 6.97346402e+00, 3.18000000e+00,
#         2.69151457e+04],
#        [7.22453376e+04, 6.09481423e+00, 5.87054501e+00, 2.01000000e+00,
#         2.55087854e+04],
#        [6.96045218e+04, 5.48795314e+00, 7.72605199e+00, 4.34000000e+00,
#         4.17859108e+04],
#        ...,
#        [6.92750473e+04, 6.13132617e+00, 6.25044768e+00, 2.50000000e+00,
#         4.01447506e+04],
#        [6.05956770e+04, 6.77300919e+00, 7.93785073e+00, 4.02000000e+00,
#         4.79919025e+04],
#        [6.92329468e+04, 5.28388234e+00, 8.05000920e+00, 5.16000000e+00,
#         2.37282407e+04]])

# %%
y_train
# Out:
# array([ 886536.42837472, 1127174.71254582, 1496177.41575075, ...,
#        1233205.19558342, 1434835.95314185, 1144319.07593362])

# %% [markdown]
# #### El Score no se estanga en ningún grado de los que hemos probado el mejor es para degree = 4.

# %% [markdown]
# ### SVR

# %%
X = df.iloc[:,-1].values.astype(float)
y = df["Price"].values.astype(float)

#3 Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X.reshape(-1, 1))
y = sc_y.fit_transform(y.reshape(-1, 1))
#4 Fitting the Support Vector Regression Model to the dataset
# Create your support vector regressor here
from sklearn.svm import SVR
# most important SVR parameter is Kernel type. It can be #linear,polynomial or gaussian SVR. We have a non-linear condition #so we can select polynomial or gaussian but here we select RBF(a #gaussian type) kernel.
regressor = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)
regressor.fit(X,y)
#5 Predicting a new result
y_pred = regressor.predict(X)
# 6 Visualización de los resultados de la regresión de vectores de soporte
plt.scatter (X, y, color = 'magenta') 
plt.plot (X, y_pred, color = 'green') 
plt.title ('USA_Housing') 
plt .xlabel ('Nivel de posición') 
plt.ylabel ('Price') 
plt.show ()

# %% [markdown]
# Comprobamos que el modelo encaja y que no tiene muchos fallos muy dispares.

# %% [markdown]
# ### 2. Se pide:
#
# En el anterior dataset, la columna "Avg. Area Number of Bedrooms" está en un rango numérico limitado:
#
# 1. Cambia todos los datos para que sean enteros redondeando hacia el entero más cercano. Si es .5 exacto, se redondea hacia abajo.
#
# 2. Cuando lo hayas hecho, tendras una columna con números enteros en un rango limitado. Ahora trata a esa columna como una serie de valores discretos (classes, labels).
#
# 3. Usando las demás columnas numéricas y una a una, utiliza SVM para clasificar esa columna modificada.
#
# 4. Usando todas las demás columnas a la vez, utiliza SVM para clasificar esa columna modificada. Es decir, "Avg. Area Income" con nuestro target, después "Avg. Area House Age", ... ¿hace aumentar el score? ¿por qué?
#
# 5. ¿Qué columna tiene mejor correlación con "Avg. Area Number of Bedrooms" una vez modificada? ¿qué columna da mejor score para nuestro target?

# %% [markdown]
# 1. Cambia todos los datos para que sean enteros redondeando hacia el entero más cercano. Si es .5 exacto, se redondea hacia abajo.

# %% [markdown]
# ______________________________

# %% [markdown]
# #### Teoría de cómo redondear decimales
# Librerías:
#
# import decimal
#
# from decimal import Decimal, getcontext
# >>> decimal.Decimal('2.5').quantize(decimal.Decimal('1'), rounding=decimal.ROUND_HALF_EVEN)
# Decimal('2')
#
# >>> decimal.Decimal('3.5').quantize(decimal.Decimal('1'), rounding=decimal.ROUND_HALF_EVEN)
# Decimal('4')
#
# >>> decimal.Decimal('3.5').quantize(decimal.Decimal('1'), rounding=decimal.ROUND_HALF_DOWN)
# Decimal('3')
#
# >>> decimal.Decimal('3.5').quantize(decimal.Decimal('1'), rounding=decimal.ROUND_HALF_UP)
# Decimal('4')
# Aplico el método que quiero en el ejercicio y por h o por b siempre me sale el número float, no soy capaz de convertilo a entero.

# %%
# Ejemplo práctico:
int(Decimal('2.7').quantize(Decimal('1'), rounding=decimal.ROUND_HALF_EVEN))
# Out:
# 3

# %%
for elem in df["Avg. Area Number of Bedrooms"].values:
    df["Avg. Area Number of Bedrooms"][df["Avg. Area Number of Bedrooms"]== elem] = int(Decimal(elem)   .quantize(Decimal('0'), rounding=decimal.ROUND_HALF_EVEN))
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
type(df["Avg. Area Number of Bedrooms"][1])
# Out:
# numpy.float64

# %% [markdown]
# Este método no me funciona porque cambia los valores pero tipo float

# %% [markdown]
# _______________________________

# %% [markdown]
# Solución del ejercicio:

# %%
df["Avg. Area Number of Bedrooms"] = df["Avg. Area Number of Bedrooms"].apply(lambda x: int(math.floor(x)))
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %% [markdown]
# 2. Cuando lo hayas hecho, tendras una columna con números enteros en un rango limitado. Ahora trata a esa columna como una serie de valores discretos (classes, labels).

# %%
type(df["Avg. Area Number of Bedrooms"][1]) # Hemos comprobado que es entero
# Out:
# numpy.int64

# %%
df["Avg. Area Number of Bedrooms"].value_counts()
# Out:
# 3    1508
# 4    1450
# 2     828
# 6     612
# 5     602
# Name: Avg. Area Number of Bedrooms, dtype: int64

# %% [markdown]
# Observamos que tenemos 5 tipos de clase: 2,3,4,5,y 6.

# %% [markdown]
# 3. Usando las demás columnas numéricas y una a una, utiliza SVM para clasificar esa columna modificada.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
X = np.array(df.drop(['Price'], 1))
y = np.array(df["Price"])

# %%
X.shape
# Out:
# (5000, 5)

# %%
y.shape
# Out:
# (5000,)

# %%
# Fit regression model
svr_rbf = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_lin = SVR(kernel='linear', C=100, gamma='auto')
svr_poly = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)

# %%
#3 Feature Scaling

X = df.drop(["Avg. Area Number of Bedrooms"],1).values.astype(float)
y = df["Avg. Area Number of Bedrooms"].values.astype(float)


sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y.reshape(-1, 1))
#4 Fitting the Support Vector Regression Model to the dataset
# Create your support vector regressor here

# most important SVR parameter is Kernel type. It can be #linear,polynomial or gaussian SVR. We have a non-linear condition #so we can select polynomial or gaussian but here we select RBF(a #gaussian type) kernel.
# regressor = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)
svr_rbf = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_lin = SVR(kernel='linear', C=100, gamma='auto')
svr_poly = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)

svr_rbf.fit(X,y)
svr_lin.fit(X,y)
svr_poly.fit(X,y)

#5 Predicting a new result
y_pred = svr_rbf.predict(X)
y_pred2 = svr_lin.predict(X)
y_pred3 = svr_poly.predict(X)

print("Predicción para modelo : ", y_pred)
print("Predicción para modelo : ", y_pred2)
print("Predicción para modelo : ", y_pred3)
# Out:
# Predicción para modelo :  [-0.10942044 -0.3794598   0.93422709 ... -0.62471089 -0.06764218
#  -0.35411183]
# Predicción para modelo :  [-0.01482506 -0.12595075  0.54416967 ... -1.02595464 -0.02177392
#  -0.17083093]
# Predicción para modelo :  [-0.00398005 -0.22673357  0.70483996 ... -0.67832756  0.00340398
#  -0.22960622]

# %%
4. Usando todas las demás columnas a la vez, utiliza SVM para clasificar esa columna modificada. Es decir, "Avg. Area Income" con nuestro target, después "Avg. Area House Age", ... ¿hace aumentar el score? ¿por qué?

# %%
for elem in df.columns[:-1]:
    # normalizamos
    sc_X = StandardScaler()
    sc_y = StandardScaler()
    X = sc_X.fit_transform(X)
    y = sc_y.fit_transform(y.reshape(-1, 1))
    # entrenamos el modelo  
    X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2)

    svr_rbf = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
    svr_lin = SVR(kernel='linear', C=100, gamma='auto')
    svr_poly = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)


    svr_rbf.fit(X,y)
    svr_lin.fit(X,y)
    svr_poly.fit(X,y)

    score = svr_rbf.score(X_test, y_test)
    score1 = svr_lin.score(X_test, y_test)
    score2 = svr_poly.score(X_test, y_test)

    print("KERNEL RBF")
    print("Score de SVR  {}:".format(elem), score)
    print("________________")
    print("KERNEL LINEAR")
    print("Score de SVR   {}:".format(elem), score1)
    print("________________")
    print("KERNEL POLY")
    print("Score de SVR  {}:".format(elem), score2)
# Out:
# KERNEL RBF
# Score de SVR  Avg. Area Income: 0.9198278785062943
# ________________
# KERNEL LINEAR
# Score de SVR   Avg. Area Income: 0.9164078807824518
# ________________
# KERNEL POLY
# Score de SVR  Avg. Area Income: 0.9169360649524346
# KERNEL RBF
# Score de SVR  Avg. Area House Age: 0.9303571530284265
# ________________
# KERNEL LINEAR
# Score de SVR   Avg. Area House Age: 0.9217333715354188
# ________________
# KERNEL POLY
# Score de SVR  Avg. Area House Age: 0.9215388185013259
# KERNEL RBF
# Score de SVR  Avg. Area Number of Rooms: 0.9244778272153229
# ________________
# KERNEL LINEAR
# Score de SVR   Avg. Area Number of Rooms: 0.9174403974912502
# ________________
# KERNEL POLY
# Score de SVR  Avg. Area Number of Rooms: 0.9175221448906041
# KERNEL RBF
# Score de SVR  Avg. Area Number of Bedrooms: 0.9291820659273935
# ________________
# KERNEL LINEAR
# Score de SVR   Avg. Area Number of Bedrooms: 0.922911326875675
# ________________
# KERNEL POLY
# ...

# %% [markdown]
# #### El mejor modelo de SVR es RBF

# %%
5. ¿Qué columna tiene mejor correlación con "Avg. Area Number of Bedrooms" una vez modificada? ¿qué columna da mejor score para nuestro target?

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>
